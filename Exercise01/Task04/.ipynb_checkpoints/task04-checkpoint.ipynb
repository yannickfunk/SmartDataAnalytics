# %%
import pandas as pd
import matplotlib as plt  
import statsmodels.api as sm
import scipy.stats as st
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error 
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ##### Read data file from folder

# %%
data_set = pd.read_csv("Credit.csv")

# %%
data_set.head(10)
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
# 5           6   80.180   8047     569      4   77         10    Male      No
# 6           7   20.996   3388     259      2   37         12  Female      No
# 7           8   71.408   7114     512      2   87          9    Male      No
# 8           9   15.125   3300     266      5   66         13  Female      No
# 9          10   71.061   6819     491      3   41         19  Female     Yes
#
#   Married         Ethnicity  Balance
# 0     Yes         Caucasian      333
# 1     Yes             Asian      903
# 2      No             Asian      580
# 3      No             Asian      964
# 4     Yes         Caucasian      331
# 5      No         Caucasian     1151
# 6      No  African American      203
# 7      No             Asian      872
# 8      No         Caucasian      279
# 9     Yes  African American     1350

# %% [markdown]
# ##### Delete first column

# %%
data_set = data_set.drop("Unnamed: 0", axis = 1)

# %% [markdown]
# ##### Some insights about the data

# %%
data_set.shape
# Out:
# (400, 11)

# %%
data_set.describe()
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %%
data_set.isnull().sum()
# Out:
# Income       0
# Limit        0
# Rating       0
# Cards        0
# Age          0
# Education    0
# Gender       0
# Student      0
# Married      0
# Ethnicity    0
# Balance      0
# dtype: int64

# %% [markdown]
#  90 cells have zero as a value in their target column

# %%
count_balance_values = data_set['Balance'].value_counts().head(5)
count_balance_values
# Out:
# 0       90
# 133      3
# 1048     3
# 531      3
# 333      2
# Name: Balance, dtype: int64

# %% [markdown]
# Check the maximum and minimum value of value in columns

# %%
max_balance = data_set['Balance'].max()
max_balance
# Out:
# 1999

# %%
min_balance = data_set['Balance'].min()
min_balance
# Out:
# 0

# %% [markdown]
# #### Subtask a

# %% [markdown]
# Used the function recommended in the task to map the categorical values to binary values

# %%
data_set = pd.get_dummies(data_set, columns = ['Gender', 'Ethnicity'])

# %%
data_set.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education Student Married  Balance  \
# 0   14.891   3606     283      2   34         11      No     Yes      333
# 1  106.025   6645     483      3   82         15     Yes     Yes      903
# 2  104.593   7075     514      4   71         11      No      No      580
# 3  148.924   9504     681      3   36         11      No      No      964
# 4   55.882   4897     357      2   68         16      No     Yes      331
#
#    Gender_Female  Gender_Male  Ethnicity_African American  Ethnicity_Asian  \
# 0              0            1                           0                0
# 1              1            0                           0                1
# 2              0            1                           0                1
# 3              1            0                           0                1
# 4              0            1                           0                0
#
#    Ethnicity_Caucasian
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %% [markdown]
# To avoid adding two columns to the existing number of columns, the two boolean values in student and married were mapped to boolean values using the python replace function

# %%
data_set[['Student', 'Married']] = data_set[['Student', 'Married']].replace({'No': 0, 'Yes': 1})

# %%
data_set.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Student  Married  Balance  \
# 0   14.891   3606     283      2   34         11        0        1      333
# 1  106.025   6645     483      3   82         15        1        1      903
# 2  104.593   7075     514      4   71         11        0        0      580
# 3  148.924   9504     681      3   36         11        0        0      964
# 4   55.882   4897     357      2   68         16        0        1      331
#
#    Gender_Female  Gender_Male  Ethnicity_African American  Ethnicity_Asian  \
# 0              0            1                           0                0
# 1              1            0                           0                1
# 2              0            1                           0                1
# 3              1            0                           0                1
# 4              0            1                           0                0
#
#    Ethnicity_Caucasian
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    1

# %% [markdown]
# #### Subtask b

# %% [markdown]
# Split the data into training and test data with 20% for test data as instructed. The train_test_split method from sklearn randomly splits the data into to parts and not in the given order in the data frame so that the data is representive.Therfore we don't have to shuffle them.

# %%
train, test = train_test_split(data_set, test_size = 0.20, random_state=1)

# %%
train.shape
# Out:
# (320, 14)

# %%
test.shape
# Out:
# (80, 14)

# %% [markdown]
# #### Subtask c

# %% [markdown]
#  Ordinary least squares is a method used for estimating the parameters of linear regression equation.

# %%
columns = ['Income','Rating', 'Cards','Age', 'Education', 'Student','Married','Gender_Female', 'Gender_Male','Ethnicity_African American','Ethnicity_Asian', 'Ethnicity_Caucasian']

# %%
train_columns = train[columns].to_numpy()

# %%
X = sm.add_constant(train_columns)

# %%
Y = train['Balance']

# %%
model = sm.OLS(Y,X) 
results = model.fit() 
results.params
# Out:
# const   -293.337323
# x1        -7.659020
# x2         3.933932
# x3         3.248996
# x4        -0.769736
# x5         0.019458
# x6       416.094243
# x7        -4.870677
# x8      -146.270822
# x9      -147.066501
# x10     -112.269516
# x11      -84.315561
# x12      -96.752246
# dtype: float64

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     635.6
# Date:                Sun, 08 May 2022   Prob (F-statistic):          1.74e-199
# Time:                        01:11:42   Log-Likelihood:                -1915.3
# No. Observations:                 320   AIC:                             3853.
# Df Residuals:                     309   BIC:                             3894.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -293.3373     18.958    -15.473      0.000    -330.640    -256.034
# x1            -7.6590      0.262    -29.271      0.000      -8.174      -7.144
# x2             3.9339      0.059     66.906      0.000       3.818       4.050
# x3             3.2490      3.985      0.815      0.416      -4.593      11.091
# x4            -0.7697      0.320     -2.407      0.017      -1.399      -0.140
# x5             0.0195      1.770      0.011      0.991      -3.462       3.501
# x6           416.0942     19.361     21.491      0.000     377.998     454.190
# x7            -4.8707     11.450     -0.425      0.671     -27.401      17.660
# x8          -146.2708     11.072    -13.211      0.000    -168.057    -124.485
# x9          -147.0665     10.879    -13.519      0.000    -168.472    -125.661
# x10         -112.2695     10.656    -10.536      0.000    -133.236     -91.303
# x11          -84.3156     10.596     -7.957      0.000    -105.166     -63.465
# x12          -96.7522      9.582    -10.098      0.000    -115.605     -77.899
# ==============================================================================
# Omnibus:                       13.164   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.127
# Skew:                           0.513   Prob(JB):                     0.000856
# Kurtosis:                       2.912   Cond. No.                     3.65e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.64e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_test = sm.add_constant(test[columns])
y_pred = results.predict(x_test)
y_pred.head()
# Out:
# 398    -106.037684
# 125      -7.964884
# 328     280.149043
# 339    1026.983979
# 172     210.964531
# dtype: float64

# %%
rmse = mean_squared_error(test['Balance'],y_pred, squared=False)
rmse
# Out:
# 122.29847133142086

# %%
normalize_rmse = rmse / 1999
normalize_rmse
# Out:
# 0.06117982557849968

# %% [markdown]
# #### Subtask d

# %%
columns_d = columns

# %%
columns_d.remove('Ethnicity_Caucasian')
columns_d
# Out:
# ['Income',
#  'Rating',
#  'Cards',
#  'Age',
#  'Education',
#  'Student',
#  'Married',
#  'Gender_Female',
#  'Gender_Male',
#  'Ethnicity_African American',
#  'Ethnicity_Asian']

# %%
train_columns_d = train[columns_d].to_numpy()

# %%
X_d = sm.add_constant(train_columns_d)

# %%
Y_d = train['Balance']

# %%
model_d = sm.OLS(Y_d,X_d) 
results_d = model_d.fit() 
results_d.params
# Out:
# const   -357.838821
# x1        -7.659020
# x2         3.933932
# x3         3.248996
# x4        -0.769736
# x5         0.019458
# x6       416.094243
# x7        -4.870677
# x8      -178.521571
# x9      -179.317250
# x10      -15.517270
# x11       12.436685
# dtype: float64

# %%
results_d.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.954
# Model:                            OLS   Adj. R-squared:                  0.952
# Method:                 Least Squares   F-statistic:                     635.6
# Date:                Sun, 08 May 2022   Prob (F-statistic):          1.74e-199
# Time:                        01:11:42   Log-Likelihood:                -1915.3
# No. Observations:                 320   AIC:                             3853.
# Df Residuals:                     309   BIC:                             3894.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -357.8388     23.584    -15.173      0.000    -404.244    -311.434
# x1            -7.6590      0.262    -29.271      0.000      -8.174      -7.144
# x2             3.9339      0.059     66.906      0.000       3.818       4.050
# x3             3.2490      3.985      0.815      0.416      -4.593      11.091
# x4            -0.7697      0.320     -2.407      0.017      -1.399      -0.140
# x5             0.0195      1.770      0.011      0.991      -3.462       3.501
# x6           416.0942     19.361     21.491      0.000     377.998     454.190
# x7            -4.8707     11.450     -0.425      0.671     -27.401      17.660
# x8          -178.5216     13.149    -13.577      0.000    -204.394    -152.649
# x9          -179.3172     12.901    -13.899      0.000    -204.702    -153.932
# x10          -15.5173     13.288     -1.168      0.244     -41.664      10.630
# x11           12.4367     13.509      0.921      0.358     -14.144      39.017
# ==============================================================================
# Omnibus:                       13.164   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.127
# Skew:                           0.513   Prob(JB):                     0.000856
# Kurtosis:                       2.912   Cond. No.                     6.74e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.06e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_test_d = sm.add_constant(test[columns_d])
y_pred_d = results_d.predict(x_test_d)

# %%
rmse_d = mean_squared_error(test['Balance'],y_pred_d, squared=False)
rmse_d
# Out:
# 122.29847133142093

# %%
normalize_rmse_d = rmse_d / 1999
normalize_rmse_d
# Out:
# 0.061179825578499714

# %%
rmse_d - rmse
# Out:
# 7.105427357601002e-14

# %% [markdown]
# #### Subtask e

# %%
def calculate_OLS(list_columns):
    
    X_ols = sm.add_constant(train[list_columns].to_numpy())
    y = train['Balance']
    mod = sm.OLS(y, X_ols)
    res = mod.fit()
    return res.summary()

# %%
list1 = ['Income', 'Limit', 'Age']
list2 =  ['Income', 'Rating', 'Age']
list3 = ['Income', 'Limit', 'Rating', 'Age']

# %%
res1 = calculate_OLS(list1)
res1
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     739.4
# Date:                Sun, 08 May 2022   Prob (F-statistic):          1.87e-142
# Time:                        01:11:42   Log-Likelihood:                -2073.6
# No. Observations:                 320   AIC:                             4155.
# Df Residuals:                     316   BIC:                             4170.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -352.9687     34.628    -10.193      0.000    -421.099    -284.838
# x1            -7.1274      0.421    -16.945      0.000      -7.955      -6.300
# x2             0.2597      0.006     40.785      0.000       0.247       0.272
# x3            -0.7208      0.516     -1.398      0.163      -1.735       0.294
# ==============================================================================
# Omnibus:                       81.620   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              147.833
# Skew:                           1.409   Prob(JB):                     7.91e-33
# Kurtosis:                       4.774   Cond. No.                     2.02e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
res2 = calculate_OLS(list2)
res2
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     784.5
# Date:                Sun, 08 May 2022   Prob (F-statistic):          4.99e-146
# Time:                        01:11:42   Log-Likelihood:                -2065.3
# No. Observations:                 320   AIC:                             4139.
# Df Residuals:                     316   BIC:                             4154.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -486.3902     35.341    -13.763      0.000    -555.924    -416.856
# x1            -7.1582      0.409    -17.493      0.000      -7.963      -6.353
# x2             3.8612      0.092     42.063      0.000       3.681       4.042
# x3            -0.8263      0.502     -1.645      0.101      -1.815       0.162
# ==============================================================================
# Omnibus:                       87.810   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              174.310
# Skew:                           1.443   Prob(JB):                     1.41e-38
# Kurtosis:                       5.177   Cond. No.                     1.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
res3 = calculate_OLS(list3) 
res3
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Balance   R-squared:                       0.882
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     589.2
# Date:                Sun, 08 May 2022   Prob (F-statistic):          8.15e-145
# Time:                        01:11:42   Log-Likelihood:                -2064.7
# No. Observations:                 320   AIC:                             4139.
# Df Residuals:                     315   BIC:                             4158.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -460.7138     42.150    -10.930      0.000    -543.646    -377.782
# x1            -7.1879      0.410    -17.536      0.000      -7.994      -6.381
# x2             0.0543      0.049      1.117      0.265      -0.041       0.150
# x3             3.0646      0.719      4.261      0.000       1.650       4.480
# x4            -0.8018      0.503     -1.595      0.112      -1.791       0.187
# ==============================================================================
# Omnibus:                       88.701   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              174.694
# Skew:                           1.467   Prob(JB):                     1.16e-38
# Kurtosis:                       5.120   Cond. No.                     2.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Interpretation of results:
# 1) Coefficients: For each variable, it is the measurement of how change in that variable affects the independent variable. It is the slope in ‘y = mx + b
# 2) Confidence interval is 95% as default, so threshold of signifigance is 0.5.
# 3)For the feature 'Age', for example,  we can't reject the null hypothesis that the feature and the target value are not independant. That is because its value is larger than 0.05.
# 4) list2 and list3 have similar R-squared value and are better than list1. The result of value of the R-squared value means the relationship between the three variables in the list and the target variable explains 88% and at the same time it is close to its adjusted R-squared value, which means no feature is irrelevant regarding the prediction.

# %% [markdown]
# #### Subtask f

# %% [markdown]
# Corrleation is a statistal measure that accesses the linear relationship between two values.
# Examples of correlation tests:
# - Pearson Korrelation
# - Spearman Korrelation
# - Kendalls Tau
#
# All three methods have a range from -1 to 1. A value of 1 indicates that two variables are positively corrleated, -1 that the are negatively correlated. 0 there is no correlation.
# Pearson will return a value of 1 if two values are linearly correlated. If the values are monotonically correlated than Spearman is a better method. Spearman can detect linearly and monotically corrleated variables. Kendalls Tau is a similar test to Spearman.

# %%
corr_pearson = data_set.corr()

# %%
corr_pearson.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e7763_row0_col0, #T_e7763_row1_col1, #T_e7763_row1_col2, #T_e7763_row2_col1, #T_e7763_row2_col2, #T_e7763_row3_col3, #T_e7763_row4_col4, #T_e7763_row5_col5, #T_e7763_row6_col6, #T_e7763_row7_col7, #T_e7763_row8_col8, #T_e7763_row9_col9, #T_e7763_row10_col10, #T_e7763_row11_col11, #T_e7763_row12_col12, #T_e7763_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col1, #T_e7763_row0_col2, #T_e7763_row1_col0, #T_e7763_row2_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col3, #T_e7763_row13_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col5, #T_e7763_row2_col5, #T_e7763_row4_col8, #T_e7763_row6_col7, #T_e7763_row10_col1, #T_e7763_row10_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col6, #T_e7763_row3_col2, #T_e7763_row4_col3, #T_e7763_row8_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col7, #T_e7763_row2_col7, #T_e7763_row11_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e7763_row0_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_e7763_row0_col9, #T_e7763_row1_col10, #T_e7763_row2_col10, #T_e7763_row7_col10, #T_e7763_row11_col9, #T_e7763_row13_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_e7763_row0_col10, #T_e7763_row1_col9, #T_e7763_row2_col9, #T_e7763_row7_col9, #T_e7763_row11_col10, #T_e7763_row13_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_e7763_row0_col11, #T_e7763_row2_col11 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_e7763_row0_col12, #T_e7763_row0_col13 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e7763_row1_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e7763_row1_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_e7763_row1_col5, #T_e7763_row4_col7, #T_e7763_row6_col1, #T_e7763_row6_col3, #T_e7763_row9_col3, #T_e7763_row10_col2, #T_e7763_row13_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e7763_row1_col6, #T_e7763_row10_col4, #T_e7763_row11_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_e7763_row1_col7, #T_e7763_row9_col6, #T_e7763_row12_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_e7763_row1_col8, #T_e7763_row2_col8, #T_e7763_row8_col1 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_e7763_row1_col11, #T_e7763_row5_col12, #T_e7763_row9_col12 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_e7763_row1_col12, #T_e7763_row2_col12, #T_e7763_row5_col13 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e7763_row1_col13, #T_e7763_row3_col11, #T_e7763_row3_col13, #T_e7763_row6_col11, #T_e7763_row8_col13 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_e7763_row2_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_e7763_row2_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e7763_row2_col6, #T_e7763_row7_col2, #T_e7763_row8_col4, #T_e7763_row10_col3, #T_e7763_row11_col1, #T_e7763_row13_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e7763_row2_col13, #T_e7763_row4_col13 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_e7763_row3_col0, #T_e7763_row5_col1, #T_e7763_row12_col0, #T_e7763_row12_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e7763_row3_col1, #T_e7763_row6_col4, #T_e7763_row7_col3, #T_e7763_row8_col5, #T_e7763_row9_col1, #T_e7763_row9_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e7763_row3_col4, #T_e7763_row3_col8 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e7763_row3_col5, #T_e7763_row5_col0, #T_e7763_row5_col3, #T_e7763_row7_col4, #T_e7763_row7_col6, #T_e7763_row9_col10, #T_e7763_row10_col8, #T_e7763_row10_col9, #T_e7763_row11_col7, #T_e7763_row12_col1, #T_e7763_row12_col2, #T_e7763_row12_col13, #T_e7763_row13_col11, #T_e7763_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e7763_row3_col6, #T_e7763_row11_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e7763_row3_col7 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e7763_row3_col9, #T_e7763_row8_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_e7763_row3_col10, #T_e7763_row8_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_e7763_row3_col12, #T_e7763_row5_col11, #T_e7763_row8_col11, #T_e7763_row10_col11, #T_e7763_row10_col13 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_e7763_row4_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_e7763_row4_col1, #T_e7763_row8_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_e7763_row4_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e7763_row4_col5, #T_e7763_row10_col5, #T_e7763_row12_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e7763_row4_col6, #T_e7763_row6_col0, #T_e7763_row9_col2, #T_e7763_row9_col5, #T_e7763_row13_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e7763_row4_col9, #T_e7763_row5_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_e7763_row4_col10, #T_e7763_row5_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e7763_row4_col11, #T_e7763_row6_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_e7763_row4_col12 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e7763_row5_col2, #T_e7763_row11_col13, #T_e7763_row13_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e7763_row5_col4, #T_e7763_row9_col4, #T_e7763_row11_col2, #T_e7763_row11_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e7763_row5_col6, #T_e7763_row5_col7 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_e7763_row5_col8, #T_e7763_row7_col8, #T_e7763_row12_col4, #T_e7763_row13_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e7763_row6_col2, #T_e7763_row11_col8, #T_e7763_row13_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e7763_row6_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_e7763_row6_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e7763_row6_col9 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e7763_row6_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_e7763_row6_col13 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_e7763_row7_col0, #T_e7763_row7_col1, #T_e7763_row11_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e7763_row7_col5 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e7763_row7_col11 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e7763_row7_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_e7763_row7_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_e7763_row8_col0 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_e7763_row8_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_e7763_row8_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e7763_row8_col12, #T_e7763_row9_col13 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_e7763_row9_col0, #T_e7763_row13_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e7763_row9_col7, #T_e7763_row13_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e7763_row9_col11, #T_e7763_row10_col12 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_e7763_row10_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e7763_row10_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e7763_row11_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e7763_row12_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e7763_row12_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e7763_row12_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_e7763_row12_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_e7763_row12_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7763">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7763_level0_col0" class="col_heading level0 col0" >Income</th>
#       <th id="T_e7763_level0_col1" class="col_heading level0 col1" >Limit</th>
#       <th id="T_e7763_level0_col2" class="

# %% [markdown]
# According to correlation matrix that is visualized above, the features that are correlated with 'Balance' the most are limit and rating. They are positively correlated to the Balance.

# %%
corr_spearman = data_set.corr(method = 'spearman') 
corr_spearman.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1f4e9_row0_col0, #T_1f4e9_row1_col1, #T_1f4e9_row2_col2, #T_1f4e9_row3_col3, #T_1f4e9_row4_col4, #T_1f4e9_row5_col5, #T_1f4e9_row6_col6, #T_1f4e9_row7_col7, #T_1f4e9_row8_col8, #T_1f4e9_row9_col9, #T_1f4e9_row10_col10, #T_1f4e9_row11_col11, #T_1f4e9_row12_col12, #T_1f4e9_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f4e9_row0_col1, #T_1f4e9_row2_col0 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_1f4e9_row0_col2 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_1f4e9_row0_col3, #T_1f4e9_row3_col0, #T_1f4e9_row3_col5, #T_1f4e9_row5_col2, #T_1f4e9_row5_col3, #T_1f4e9_row7_col4, #T_1f4e9_row7_col6, #T_1f4e9_row9_col10, #T_1f4e9_row10_col8, #T_1f4e9_row10_col9, #T_1f4e9_row11_col7, #T_1f4e9_row12_col1, #T_1f4e9_row12_col2, #T_1f4e9_row12_col13, #T_1f4e9_row13_col11, #T_1f4e9_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1f4e9_row0_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_1f4e9_row0_col5, #T_1f4e9_row5_col1, #T_1f4e9_row11_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1f4e9_row0_col6, #T_1f4e9_row1_col6, #T_1f4e9_row2_col6, #T_1f4e9_row3_col2, #T_1f4e9_row7_col2, #T_1f4e9_row9_col4, #T_1f4e9_row10_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_1f4e9_row0_col7, #T_1f4e9_row4_col2, #T_1f4e9_row9_col7, #T_1f4e9_row13_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_1f4e9_row0_col8, #T_1f4e9_row0_col13, #T_1f4e9_row1_col13, #T_1f4e9_row2_col13 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_1f4e9_row0_col9, #T_1f4e9_row5_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_1f4e9_row0_col10, #T_1f4e9_row5_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_1f4e9_row0_col11, #T_1f4e9_row7_col13, #T_1f4e9_row8_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_1f4e9_row0_col12, #T_1f4e9_row1_col12, #T_1f4e9_row2_col12 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_1f4e9_row1_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_1f4e9_row1_col2, #T_1f4e9_row2_col1 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_1f4e9_row1_col3, #T_1f4e9_row10_col5, #T_1f4e9_row12_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1f4e9_row1_col4, #T_1f4e9_row2_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_1f4e9_row1_col5, #T_1f4e9_row10_col2, #T_1f4e9_row12_col4, #T_1f4e9_row13_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1f4e9_row1_col7, #T_1f4e9_row6_col5, #T_1f4e9_row9_col6, #T_1f4e9_row12_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_1f4e9_row1_col8, #T_1f4e9_row2_col8, #T_1f4e9_row8_col1, #T_1f4e9_row8_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_1f4e9_row1_col9, #T_1f4e9_row12_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_1f4e9_row1_col10, #T_1f4e9_row12_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_1f4e9_row1_col11, #T_1f4e9_row2_col11, #T_1f4e9_row10_col11, #T_1f4e9_row10_col13 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_1f4e9_row2_col3, #T_1f4e9_row3_col8, #T_1f4e9_row7_col5, #T_1f4e9_row8_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1f4e9_row2_col4, #T_1f4e9_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_1f4e9_row2_col5, #T_1f4e9_row5_col0, #T_1f4e9_row12_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_1f4e9_row2_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_1f4e9_row2_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_1f4e9_row3_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_1f4e9_row3_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1f4e9_row3_col6, #T_1f4e9_row4_col6, #T_1f4e9_row6_col1, #T_1f4e9_row6_col4, #T_1f4e9_row8_col5, #T_1f4e9_row13_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1f4e9_row3_col7, #T_1f4e9_row12_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_1f4e9_row3_col9, #T_1f4e9_row4_col10, #T_1f4e9_row7_col10, #T_1f4e9_row11_col9, #T_1f4e9_row13_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_1f4e9_row3_col10, #T_1f4e9_row4_col9, #T_1f4e9_row7_col9, #T_1f4e9_row11_col10, #T_1f4e9_row13_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_1f4e9_row3_col11, #T_1f4e9_row3_col12, #T_1f4e9_row5_col11, #T_1f4e9_row8_col11 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_1f4e9_row3_col13, #T_1f4e9_row9_col13 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_1f4e9_row4_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1f4e9_row4_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_1f4e9_row4_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1f4e9_row4_col5, #T_1f4e9_row6_col0, #T_1f4e9_row8_col4, #T_1f4e9_row9_col1, #T_1f4e9_row9_col2, #T_1f4e9_row9_col8, #T_1f4e9_row10_col3, #T_1f4e9_row11_col3, #T_1f4e9_row13_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_1f4e9_row4_col7, #T_1f4e9_row4_col8, #T_1f4e9_row6_col7, #T_1f4e9_row10_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1f4e9_row4_col11, #T_1f4e9_row6_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_1f4e9_row4_col12 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_1f4e9_row4_col13, #T_1f4e9_row6_col11 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_1f4e9_row5_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_1f4e9_row5_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_1f4e9_row5_col8, #T_1f4e9_row6_col3, #T_1f4e9_row13_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_1f4e9_row5_col12, #T_1f4e9_row9_col12 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1f4e9_row5_col13 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_1f4e9_row6_col2, #T_1f4e9_row9_col5, #T_1f4e9_row10_col0, #T_1f4e9_row11_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1f4e9_row6_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_1f4e9_row6_col9 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_1f4e9_row6_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_1f4e9_row6_col13 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_1f4e9_row7_col0, #T_1f4e9_row10_col4 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1f4e9_row7_col1, #T_1f4e9_row13_col0, #T_1f4e9_row13_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1f4e9_row7_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_1f4e9_row7_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_1f4e9_row7_col11, #T_1f4e9_row8_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_1f4e9_row7_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_1f4e9_row8_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_1f4e9_row8_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_1f4e9_row8_col9 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_1f4e9_row8_col10 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_1f4e9_row8_col12, #T_1f4e9_row9_col11, #T_1f4e9_row10_col12 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_1f4e9_row9_col0, #T_1f4e9_row11_col2, #T_1f4e9_row11_col5, #T_1f4e9_row13_col1 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_1f4e9_row9_col3, #T_1f4e9_row11_col8, #T_1f4e9_row13_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_1f4e9_row10_col1, #T_1f4e9_row12_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1f4e9_row11_col0, #T_1f4e9_row11_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1f4e9_row11_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_1f4e9_row11_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_1f4e9_row12_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1f4e9_row12_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1f4e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f4e9_level0_col0" class="col_heading level0 col0" >Income</th>
#       <th id="T_1f4e9_level0_col1" class="col_heading level0 col1" >Limit</th>
#       <th id="T_1f4e9_level0_col2" class="

# %%
corr_kendall = data_set.corr(method = 'kendall') 
corr_kendall.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ab08e_row0_col0, #T_ab08e_row1_col1, #T_ab08e_row2_col2, #T_ab08e_row3_col3, #T_ab08e_row4_col4, #T_ab08e_row5_col5, #T_ab08e_row6_col6, #T_ab08e_row7_col7, #T_ab08e_row8_col8, #T_ab08e_row9_col9, #T_ab08e_row10_col10, #T_ab08e_row11_col11, #T_ab08e_row12_col12, #T_ab08e_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ab08e_row0_col1, #T_ab08e_row2_col0, #T_ab08e_row3_col9, #T_ab08e_row7_col10, #T_ab08e_row11_col9, #T_ab08e_row13_col9 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ab08e_row0_col2, #T_ab08e_row1_col10, #T_ab08e_row2_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_ab08e_row0_col3, #T_ab08e_row3_col0, #T_ab08e_row3_col5, #T_ab08e_row5_col3, #T_ab08e_row7_col4, #T_ab08e_row7_col6, #T_ab08e_row9_col10, #T_ab08e_row10_col8, #T_ab08e_row10_col9, #T_ab08e_row11_col7, #T_ab08e_row12_col1, #T_ab08e_row12_col2, #T_ab08e_row12_col13, #T_ab08e_row13_col11, #T_ab08e_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ab08e_row0_col4, #T_ab08e_row11_col12 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_ab08e_row0_col5, #T_ab08e_row5_col0, #T_ab08e_row5_col2, #T_ab08e_row11_col13, #T_ab08e_row12_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ab08e_row0_col6, #T_ab08e_row1_col6, #T_ab08e_row2_col6, #T_ab08e_row10_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ab08e_row0_col7, #T_ab08e_row6_col5, #T_ab08e_row9_col7, #T_ab08e_row13_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ab08e_row0_col8 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ab08e_row0_col9, #T_ab08e_row4_col9, #T_ab08e_row5_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_ab08e_row0_col10, #T_ab08e_row1_col0, #T_ab08e_row4_col10, #T_ab08e_row5_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ab08e_row0_col11, #T_ab08e_row2_col11, #T_ab08e_row8_col13, #T_ab08e_row10_col11, #T_ab08e_row10_col13 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_ab08e_row0_col12, #T_ab08e_row2_col12 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ab08e_row0_col13, #T_ab08e_row7_col13 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ab08e_row1_col2, #T_ab08e_row2_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_ab08e_row1_col3, #T_ab08e_row4_col7, #T_ab08e_row6_col1, #T_ab08e_row6_col4, #T_ab08e_row8_col5, #T_ab08e_row9_col5, #T_ab08e_row13_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ab08e_row1_col4, #T_ab08e_row2_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_ab08e_row1_col5, #T_ab08e_row4_col8, #T_ab08e_row6_col3, #T_ab08e_row12_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ab08e_row1_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ab08e_row1_col8, #T_ab08e_row2_col8, #T_ab08e_row8_col1 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_ab08e_row1_col9, #T_ab08e_row2_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_ab08e_row1_col11, #T_ab08e_row3_col11, #T_ab08e_row3_col12, #T_ab08e_row5_col11, #T_ab08e_row8_col11 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_ab08e_row1_col12, #T_ab08e_row5_col13 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ab08e_row1_col13, #T_ab08e_row2_col13 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ab08e_row2_col3, #T_ab08e_row9_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ab08e_row2_col5, #T_ab08e_row10_col2, #T_ab08e_row13_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ab08e_row2_col7, #T_ab08e_row9_col6, #T_ab08e_row12_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col4, #T_ab08e_row8_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col6, #T_ab08e_row4_col6, #T_ab08e_row7_col0, #T_ab08e_row9_col1, #T_ab08e_row10_col3, #T_ab08e_row11_col3, #T_ab08e_row11_col5, #T_ab08e_row13_col1, #T_ab08e_row13_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col7, #T_ab08e_row4_col2, #T_ab08e_row7_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col8, #T_ab08e_row4_col1, #T_ab08e_row4_col3, #T_ab08e_row11_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ab08e_row3_col10, #T_ab08e_row7_col9, #T_ab08e_row11_col10, #T_ab08e_row13_col10 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_ab08e_row3_col13, #T_ab08e_row9_col13 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ab08e_row4_col0, #T_ab08e_row5_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ab08e_row4_col5, #T_ab08e_row6_col0, #T_ab08e_row11_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ab08e_row4_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_ab08e_row4_col12, #T_ab08e_row6_col13 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ab08e_row4_col13, #T_ab08e_row6_col11 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ab08e_row5_col1, #T_ab08e_row10_col1, #T_ab08e_row12_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ab08e_row5_col4, #T_ab08e_row7_col2, #T_ab08e_row12_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ab08e_row5_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ab08e_row5_col8, #T_ab08e_row6_col7, #T_ab08e_row7_col3, #T_ab08e_row10_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_ab08e_row5_col12, #T_ab08e_row9_col12 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ab08e_row6_col2, #T_ab08e_row9_col0, #T_ab08e_row10_col5, #T_ab08e_row11_col1, #T_ab08e_row12_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ab08e_row6_col8 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ab08e_row6_col9 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_ab08e_row6_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_ab08e_row6_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_ab08e_row7_col1, #T_ab08e_row13_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ab08e_row7_col8, #T_ab08e_row13_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ab08e_row7_col11 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ab08e_row7_col12 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_ab08e_row8_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ab08e_row8_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_ab08e_row8_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ab08e_row8_col4, #T_ab08e_row9_col2, #T_ab08e_row9_col8, #T_ab08e_row10_col4, #T_ab08e_row11_col0, #T_ab08e_row13_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ab08e_row8_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_ab08e_row8_col9, #T_ab08e_row12_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_ab08e_row8_col10, #T_ab08e_row12_col10 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_ab08e_row8_col12 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_ab08e_row9_col3, #T_ab08e_row10_col0, #T_ab08e_row11_col8, #T_ab08e_row13_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ab08e_row9_col11, #T_ab08e_row10_col12 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ab08e_row11_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ab08e_row12_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ab08e_row12_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ab08e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab08e_level0_col0" class="col_heading level0 col0" >Income</th>
#       <th id="T_ab08e_level0_col1" class="col_heading level0 col1" >Limit</th>
#       <th id="T_ab08e_level0_col2" class="col_heading level0 col2" >Rating</th>
#       <th id="T_ab08e_level0_col3" class="col_heading level0 col3" >Cards</th>
#       <th id="T_ab08e_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_ab08e_level0_col5" class="col_heading level0 col5" >Education</th>
#       <th id="T_ab08e_l

# %% [markdown]
# All three show the same correlations with difference in the value of the corrlation, but all have high corellations between the same values.

# %% [markdown]
# #### Subtask g

# %%
list_states = [1, 33, 135, 123, 99, 22, 100]

# %%
all_lists = [list1, list, list3]

# %%
def create_forest(list_states): 
    result = [] 
    for l in all_lists:
        inner = [] 
        for val in list_states: 
            X = train[l].to_numpy()
            #print(X.shape)
            y = train['Balance'] 
            rf = RandomForestRegressor(random_state = val) 
            rf.fit(X,y) 
            y_pred= rf.predict(test[l])
            sqr = mean_squared_error(y_pred, test['Balance'])
            inner.append(sqr)
        result.append(inner)
    return result

# %%
create_forest(list_states)
# Out:
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# C:\Users\olaei\anaconda3\envs\psdag03\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# [[38949.1022375,
#   38757.419825000004,
#   37358.242906249994,
#   38897.991799999996,
#   38245.20931375,
#   39529.274866249994,
#   38346.645053750006],
#  [451.8151562500001,
#   535.3746662500002,
#   637.8586812500005,
#   741.6010887500003,
#   541.5142362500001,
#   659.7987224999991,
#   497.11505500000004],
#  [37577.587396250005,
#   37567.40571,
#   38429.423196250005,
#   37378.34696625,
#   37549.796665,
#   37815.87270749999,
#   38441.44925125]]

# %% [markdown]
# Different values according to the random states

# %% [markdown]
# #### Subtask h

# %% [markdown]
# Multicollinearity refers to the condition in which two or more independant variables (predictors) are highly correlated. This means one variable can be used to predict the other. It is considered a problem because one cannot identify which variable has the most effect on the target variable. Morever, this may cause a poor estimation of the regression coeffcients.

# %% [markdown]
# Variance inflation factor (VIF) can be used to detect multicollinearity by identifying correlations between variables and determine the strength of the relationships.

# %% [markdown]
# Possible solutions:
# 1) Remove some highly correlated variables
# 2) Combine the independant variables linearly
# 3) Use forms of regression analysis that can handle multicollinearity, such as: LASSO and ridge regressions.
